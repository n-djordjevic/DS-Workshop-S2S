# %% [markdown]
# # Meet Pandas<br>
# <a href='https://pandas.pydata.org/'>Pandas</a> is one of the most famous Python libraries used in the machine learning pipeline. Pandas allows us to load data from files with extensions like `.csv`, `.tsv` or `.xlsx`, which are the most used file formats for storing data in practice.<br>
# Two data structures Pandas provides are `Series` and `DataFrame`. `Series` data structure is a one-dimensional indexed array of a certain type. `DataFrame`, on the other hand, is a two-dimensional array (matrix) where each of the columns is of a certain type. In other words, `DataFrame` is a table where each row is one observation or an instance (a person, a day, an object...) and each column is an attribute (called a feature) for which every row has a value.<br>
# Besides reading the data into a useful format, using Pandas you can:
# <ul><li>manipulate data</li>
#     <li>explore data</li>
#     <li>perform statistical metrics on data</li>
#     <li>merge multiple datasets</li></ul><br>
#     and so on...<br>
#     We'll also import <a href='https://numpy.org/'>NumPy</a> (Numerical Python) library, which is another important library mostly used for linear algebra. Because of that, most of the functions in Pandas use the NumPy library. That's the reason why we need to import them both in order to use Pandas.<br>
# The dataset we'll be using can be found on <a href='https://www.kaggle.com/becksddf/churn-in-telecoms-dataset'>this link</a>.

# %% [markdown]
# ## Reading the Data<br>
# Multiple different Pandas functions can be used to read the data depending on the file format. Since the dataset we downloaded is in `.csv` format, we will use `pandas.read_csv()` function.<br>Before we begin, we need to import the libraries and use aliases so that we don't need to write the full names of the libraries when we want to use them.<br>
# We can use `set_option()` function in Pandas to customize our Pandas experience. Here we set maximum number of columns to display to 25 (default is 20) and to round each number to 2 decimal points (default is 6).

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max.columns', 25)
pd.set_option("display.precision", 2)

# %%
df = pd.read_csv('data/churn.csv')

# %% [markdown]
# ## Data Inspection<br>
# Now that we have our data loaded, we need to get familiar with it before we can start using machine learning algorithms.
# One of the most frequently used functions to inspect our dataset is `head()` -  it shows the first 5 rows of our dataset.

# %%
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
# 2              0     243.4        114       41.38     121.2        110
# 3              0     299.4         71       50.90      61.9         88
# 4              0     166.7        113       28.34     148.3        122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1   False
# 1         3.70               1   False
# 2         3.29               0   False
# 3         1.78               2   False
# 4         2.73               3   False

# %%
print(f'The function shape() prints out the shape of our DataFrame: {df.shape}.\n \
That is, how many rows and columns it has. The format is (rows, columns).')
# Out:
# The function shape() prints out the shape of our DataFrame: (3333, 21).
#  That is, how many rows and columns it has. The format is (rows, columns).

# %% [markdown]
# If we want to have a more detailed look at our data, see the types of each column and how many entries each one has, we can use `info()` function.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# State             3333 non-null object
# Account Length    3333 non-null int64
# Area Code         3333 non-null int64
# Phone             3333 non-null object
# Int'l Plan        3333 non-null object
# VMail Plan        3333 non-null object
# VMail Message     3333 non-null int64
# Day Mins          3333 non-null float64
# Day Calls         3333 non-null int64
# Day Charge        3333 non-null float64
# Eve Mins          3333 non-null float64
# Eve Calls         3333 non-null int64
# Eve Charge        3333 non-null float64
# Night Mins        3333 non-null float64
# Night Calls       3333 non-null int64
# Night Charge      3333 non-null float64
# Intl Mins         3333 non-null float64
# Intl Calls        3333 non-null int64
# Intl Charge       3333 non-null float64
# CustServ Calls    3333 non-null int64
# Churn?            3333 non-null bool
# dtypes: bool(1), float64(8), int64(8), object(4)
# memory usage: 524.1+ KB

# %% [markdown]
# What's interesting, besides having all of the different types - int64, float64, bool, object - `object` type is used to represent categorical features. A feature is categorical when the possible values for that feature are limited (and usually text): yes - no, green - red - yellow, male-female...<br>
# Another way we can have a more in-depth look at our data is by using `describe()` function. It shows different statistical measures for each numeric feature, unless specified otherwise.

# %%
df.describe()
# Out:
#        Account Length  Area Code  VMail Message  Day Mins  Day Calls  \
# count         3333.00    3333.00        3333.00   3333.00    3333.00
# mean           101.06     437.18           8.10    179.78     100.44
# std             39.82      42.37          13.69     54.47      20.07
# min              1.00     408.00           0.00      0.00       0.00
# 25%             74.00     408.00           0.00    143.70      87.00
# 50%            101.00     415.00           0.00    179.40     101.00
# 75%            127.00     510.00          20.00    216.40     114.00
# max            243.00     510.00          51.00    350.80     165.00
#
#        Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# count     3333.00   3333.00    3333.00     3333.00     3333.00      3333.00
# mean        30.56    200.98     100.11       17.08      200.87       100.11
# std          9.26     50.71      19.92        4.31       50.57        19.57
# min          0.00      0.00       0.00        0.00       23.20        33.00
# 25%         24.43    166.60      87.00       14.16      167.00        87.00
# 50%         30.50    201.40     100.00       17.12      201.20       100.00
# 75%         36.79    235.30     114.00       20.00      235.30       113.00
# max         59.64    363.70     170.00       30.91      395.00       175.00
#
#        Night Charge  Intl Mins  Intl Calls  Intl Charge  CustServ Calls
# count       3333.00    3333.00     3333.00      3333.00         3333.00
# mean           9.04      10.24        4.48         2.76            1.56
# std            2.28       2.79        2.46         0.75            1.32
# min            1.04       0.00        0.00         0.00            0.00
# 25%            7.52       8.50        3.00         2.30            1.00
# 50%            9.05      10.30        4.00         2.78            1.00
# 75%           10.59      12.10        6.00         3.27            2.00
# max           17.77      20.00       20.00         5.40            9.00

# %% [markdown]
# If we wanted to have a similar look at the non-numerical features, we can do that by using the parameter include and provide it the list of the types of features we want to have a look at. Since these aren't numerical features we can't use the same statistical measure as before.

# %%
df.describe(include=['object', 'bool'])
# Out:
#        State     Phone Int'l Plan VMail Plan Churn?
# count   3333      3333       3333       3333   3333
# unique    51      3333          2          2      2
# top       WV  378-9029         no         no  False
# freq     106         1       3010       2411   2850

# %% [markdown]
# How can we see the distribution of categorical features? For an example, how can we see how many churners and non-churners are in our dataset? Like the following:

# %%
df['Churn?'].value_counts(normalize=True)
# Out:
# False    0.86
# True     0.14
# Name: Churn?, dtype: float64

# %% [markdown]
# By setting the normalize parameter to True, the distribution will be shown in percentages.<br>
# There are 86% of clients that aren't churning and 14% of them are churners and that's a really big number to have if the bank wants to be successful..

# %% [markdown]
# ## Data Manipulation<br>
# ### Basic Feature Engineering<br>
# Before we can start our machine learning engines, we need to convert categorical features into numerical ones, because computers, as we all know, "think" in numbers. There are three ways we can do this.<br>
# First on the go is `astype()` function. We'll turn `Churn?` column from boolean to an integer. For the change to be saved, we need to save the newly changed column to itself.

# %%
df['Churn?'] = df['Churn?'].astype('int64')
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
# 2              0     243.4        114       41.38     121.2        110
# 3              0     299.4         71       50.90      61.9         88
# 4              0     166.7        113       28.34     148.3        122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1       0
# 1         3.70               1       0
# 2         3.29               0       0
# 3         1.78               2       0
# 4         2.73               3       0

# %% [markdown]
# Another way of doing this is by using the `map()` function which works with dictionaries. Dictionary is a collection of key:value pairs. To save the changes we do the same as before.

# %%
d = {'yes': 1, 'no': 0}
df['Int\'l Plan'] = df['Int\'l Plan'].map(d)
df.head()
# Out:
#   State  Account Length  Area Code     Phone  Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657           0        yes
# 1    OH             107        415  371-7191           0        yes
# 2    NJ             137        415  358-1921           0         no
# 3    OH              84        408  375-9999           1         no
# 4    OK              75        415  330-6626           1         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
# 2              0     243.4        114       41.38     121.2        110
# 3              0     299.4         71       50.90      61.9         88
# 4              0     166.7        113       28.34     148.3        122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1       0
# 1         3.70               1       0
# 2         3.29               0       0
# 3         1.78               2       0
# 4         2.73               3       0

# %% [markdown]
# The third function is `replace()`. It works the same as `map()`, but the changes can be saved when the inplace parameter is set to True.

# %%
df['VMail Plan'].replace(d, inplace=True)
df.head()
# Out:
#   State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan  \
# 0    KS             128        415  382-4657           0           1
# 1    OH             107        415  371-7191           0           1
# 2    NJ             137        415  358-1921           0           0
# 3    OH              84        408  375-9999           1           0
# 4    OK              75        415  330-6626           1           0
#
#    VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0             25     265.1        110       45.07     197.4         99
# 1             26     161.6        123       27.47     195.5        103
# 2              0     243.4        114       41.38     121.2        110
# 3              0     299.4         71       50.90      61.9         88
# 4              0     166.7        113       28.34     148.3        122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1       0
# 1         3.70               1       0
# 2         3.29               0       0
# 3         1.78               2       0
# 4         2.73               3       0

# %% [markdown]
# ### Subsetting<br>
# Subsetting is selecting a certain subset of the data we have. For example, selecting only the people that did churn. We usually use conditionals here in the form of df[L(df['NameOfColumn'])] where L() is conditional function.

# %%
df[df['Churn?'] == 1].head()
# Out:
#    State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan  \
# 10    IN              65        415  329-6603           0           0
# 15    NY             161        415  351-7269           0           0
# 21    CO              77        408  393-7984           0           0
# 33    AZ              12        408  360-1596           0           0
# 41    MD             135        408  383-6029           1           1
#
#     VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 10              0     129.1        137       21.95     228.5         83
# 15              0     332.9         67       56.59     317.8         97
# 21              0      62.4         89       10.61     169.9        121
# 33              0     249.6        118       42.43     252.4        119
# 41             41     173.1         85       29.43     203.9        107
#
#     Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 10       19.42       208.8          111          9.40       12.7           6
# 15       27.01       160.6          128          7.23        5.4           9
# 21       14.44       209.6           64          9.43        5.7           6
# 33       21.45       280.2           90         12.61       11.8           3
# 41       17.33       122.2           78          5.50       14.6          15
#
#     Intl Charge  CustServ Calls  Churn?
# 10         3.43               4       1
# 15         1.46               4       1
# 21         1.54               5       1
# 33         3.19               1       1
# 41         3.94               0       1

# %%
df[(df['Churn?'] == 1) & (df['Day Calls'] > 100)].head()
# Out:
#    State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan  \
# 10    IN              65        415  329-6603           0           0
# 33    AZ              12        408  360-1596           0           0
# 48    ID             119        415  398-1294           0           0
# 57    CO             121        408  370-7574           0           1
# 69    TX             150        510  374-8042           0           0
#
#     VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 10              0     129.1        137       21.95     228.5         83
# 33              0     249.6        118       42.43     252.4        119
# 48              0     159.1        114       27.05     231.3        117
# 57             30     198.4        129       33.73      75.3         77
# 69              0     178.9        101       30.41     169.1        110
#
#     Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 10       19.42       208.8          111          9.40       12.7           6
# 33       21.45       280.2           90         12.61       11.8           3
# 48       19.66       143.2           91          6.44        8.8           3
# 57        6.40       181.2           77          8.15        5.8           3
# 69       14.37       148.6          100          6.69       13.8           3
#
#     Intl Charge  CustServ Calls  Churn?
# 10         3.43               4       1
# 33         3.19               1       1
# 48         2.38               5       1
# 57         1.57               3       1
# 69         3.73               4       1

# %% [markdown]
# Although, more commonly used functions for subsetting are `loc[]` and `iloc[]` functions. The former can be used to subset using the <b>names</b> of the columns, and the latter can be used to subset using the <b>indexes</b> of the columns.

# %%
df.loc[0:10, ['Day Calls', 'Eve Calls', 'Night Calls']]
# Out:
#     Day Calls  Eve Calls  Night Calls
# 0         110         99           91
# 1         123        103          103
# 2         114        110          104
# 3          71         88           89
# 4         113        122          121
# 5          98        101          118
# 6          88        108          118
# 7          79         94           96
# 8          97         80           90
# 9          84        111           97
# 10        137         83          111

# %%
df.iloc[-10:, [8, 11, 14]]
# Out:
#       Day Calls  Eve Calls  Night Calls
# 3323        126         97           56
# 3324        114        105           82
# 3325         99         88          109
# 3326        128         87           92
# 3327         98         68          128
# 3328         77        126           83
# 3329         57         55          123
# 3330        109         58           91
# 3331        105         84          137
# 3332        113         82           77

# %%
df[df['Churn?'] == 1].mean()
# Out:
# Account Length    102.664596
# Area Code         437.817805
# VMail Message       5.115942
# Day Mins          206.914079
# Day Calls         101.335404
# Day Charge         35.175921
# Eve Mins          212.410145
# Eve Calls         100.561077
# Eve Charge         18.054969
# Night Mins        205.231677
# Night Calls       100.399586
# Night Charge        9.235528
# Intl Mins          10.700000
# Intl Calls          4.163561
# Intl Charge         2.889545
# CustServ Calls      2.229814
# Churn?              1.000000
# dtype: float64

# %% [markdown]
# ### Setting different index<br>
# Sometimes, we have a feature that is unique with every observation - in our case, that's phone number for every client. We can set this feature to be our identifier for each client, and like before we'll use inplace parameter to save the changes.

# %%
df.set_index(df['Phone'], inplace=True)
df.head()
# Out:
#          State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan  \
# Phone
# 382-4657    KS             128        415  382-4657           0           1
# 371-7191    OH             107        415  371-7191           0           1
# 358-1921    NJ             137        415  358-1921           0           0
# 375-9999    OH              84        408  375-9999           1           0
# 330-6626    OK              75        415  330-6626           1           0
#
#           VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# Phone
# 382-4657             25     265.1        110       45.07     197.4         99
# 371-7191             26     161.6        123       27.47     195.5        103
# 358-1921              0     243.4        114       41.38     121.2        110
# 375-9999              0     299.4         71       50.90      61.9         88
# 330-6626              0     166.7        113       28.34     148.3        122
#
#           Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# Phone
# 382-4657       16.78       244.7           91         11.01       10.0
# 371-7191       16.62       254.4          103         11.45       13.7
# 358-1921       10.30       162.6          104          7.32       12.2
# 375-9999        5.26       196.9           89          8.86        6.6
# 330-6626       12.61       186.9          121          8.41       10.1
#
#           Intl Calls  Intl Charge  CustServ Calls  Churn?
# Phone
# 382-4657           3         2.70               1       0
# 371-7191           3         3.70               1       0
# 358-1921           5         3.29               0       0
# 375-9999           7         1.78               2       0
# 330-6626           3         2.73               3       0

# %% [markdown]
# ### Missing Values<br>
# In some cases, there will be missing values for some observations. Maybe we won't know the exact State of the client, or we somehow lost the value of Day Minutes for a client. We can check if we have missing values with the function `isna()`.

# %%
df.isna()
# Out:
#           State  Account Length  Area Code  Phone  Int'l Plan  VMail Plan  \
# Phone
# 382-4657  False           False      False  False       False       False
# 371-7191  False           False      False  False       False       False
# 358-1921  False           False      False  False       False       False
# 375-9999  False           False      False  False       False       False
# 330-6626  False           False      False  False       False       False
# 391-8027  False           False      False  False       False       False
# 355-9993  False           False      False  False       False       False
# 329-9001  False           False      False  False       False       False
# 335-4719  False           False      False  False       False       False
# 330-8173  False           False      False  False       False       False
# 329-6603  False           False      False  False       False       False
# 344-9403  False           False      False  False       False       False
# 363-1107  False           False      False  False       False       False
# 394-8006  False           False      False  False       False       False
# 366-9238  False           False      False  False       False       False
# 351-7269  False           False      False  False       False       False
# 350-8884  False           False      False  False       False       False
# 386-2923  False           False      False  False       False       False
# 356-2992  False           False      False  False       False       False
# 373-2782  False           False      False  False       False       False
# 396-5800  False           False      False  False       False       False
# 393-7984  False           False      False  False       False       False
# 358-1958  False           False      False  False       False       False
# 350-2565  False           False      False  False       False       False
# 343-4696  False           False      False  False       False       False
# 331-3698  False           False      False  False       False       False
# 357-3817  False           False      False  False       False       False
# 418-6412  False           False      False  False       False       False
# 353-2630  False           False      False  False       False       False
# 410-7789  False           False      False  False       False       False
# ...         ...             ...        ...    ...         ...         ...
# 373-7308  False           False      False  False       False       False
# 330-7137  False           False      False  False       False       False
# 406-8445  False           False      False  False       False       False
# 404-5283  False           False      False  False       False       False
# 398-3632  False           False      False  False       False       False
# 399-5763  False           False      False  False       False       False
# 340-9449  False           False      False  False       False       False
# 363-1123  False           False      False  False       False       False
# 361-2170  False           False      False  False       False       False
# 406-6304  False           False      False  False       False       False
# 392-5090  False           False      False  False       False       False
# 373-7713  False           False      False  False       False       False
# 392-1376  False           False      False  False       False       False
# 390-6388  False           False      False  False       False       False
# 379-7290  False           False      False  False       False       False
# 397-9928  False           False      False  False       False       False
# 378-6924  False           False      False  False       False       False
# 411-5677  False           False      False  False       False       False
# 400-2738  False           False      False  False       False       False
# 409-1856  False           False      False  False       False       False
# 362-5899  False           False      False  False       False       False
# 377-1164  False           False      False  False       False       False
# 368-8555  False           False      False  False       False       False
# 347-6812  False           False      False  False       False       False
# 348-3830  False           False      False  False       False       False
# 414-4276  False           False      False  False       False       False
# 370-3271  False           False      False  False       False       False
# 328-8230  False           False      False  False       False       False
# 364-6381  False           False      False  False       False       False
# 400-4344  False           False      False  False       False       False
#
#           VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# Phone
# 382-4657          False     False      False       False     False      False
# 371-7191          False     False      False       False     False      False
# 358-1921          False     False      False       False     False      False
# 375-9999          False     False      False       False     False      False
# 330-6626          False     False      False       False     False      False
# 391-8027          False     False      False       False     False      False
# 355-9993          False     False      False       False     False      False
# 329-9001          False     False      False       False     False      False
# 335-4719          False     False      False       False     False      False
# 330-8173          False     False      False       False     False      False
# 329-6603          False     False      False       False     False      False
# 344-9403          False     False      False       False     False      False
# 363-1107          False     False      False       False     False      False
# 394-8006          False     False      False       False     False      False
# 366-9238          False     False      False       False     False      False
# 351-7269          False     False      False       False     False      False
# 350-8884          False     False      False       False     False      False
# 386-2923          False     False      False       False     False      False
# 356-2992          False     False      False       False     False      False
# 373-2782          False     False      False       False     False      False
# 396-5800          False     False      False       False     False      False
# 393-7984          False     False      False       False     False      False
# 358-1958          False     False      False       False     False      False
# 350-2565          False     False      False       False     False      False
# 343-4696          False     False      False       False     False      False
# 331-3698          False     False      False       False     False      False
# 357-3817          False     False      False       False     False      False
# 418-6412          False     False      False       False     False      False
# 353-2630          False     False      False       False     False      False
# 410-7789          False     False      False       False     False      False
# ...                 ...       ...        ...         ...       ...        ...
# 373-7308          False     False      False       False     False      False
# 330-7137          False     False      False       False     False      False
# 406-8445          False     False      False       False     False      False
# 404-5283          False     False      False       False     False      False
# 398-3632          False     False      False       False     False      False
# 399-5763          False     False      False       False     False      False
# 340-9449          False     False      False       False     False      False
# 363-1123          False     False      False       False     False      False
# 361-2170          False     False      False       False     False      False
# 406-6304          False     False      False       False     False      False
# 392-5090          False     False      False       False     False      False
# 373-7713          False     False      False       False     False      False
# 392-1376          False     False      False       False     False      False
# 390-6388          False     False      False       False     False      False
# 379-7290          False     False      False       False     False      False
# 397-9928          False     False      False       False     False      False
# 378-6924          False     False      False       False     False      False
# 411-5677          False     False      False       False     False      False
# 400-2738          False     False      False       False     False      False
# 409-1856          False     False      False       False     False      False
# 362-5899          False     False      False       False     False      False
# 377-1164          False     False      False       False     False      False
# 368-8555          False     False      False       False     False      False
# 347-6812          False     False      False       False     False      False
# 348-3830          False     False      False       False     False      False
# 414-4276          False     False      False       False     False      False
# 370-3271          False     False      False       False     False      False
# 328-8230          False     False      False       False     False      False
# 364-6381          False     False      False       False     False      False
# 400-4344          False     False      False       False     False      False
#
#           Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# Phone
# 382-4657       False       False        False         False      False
# 371-7191       False       False        False         False      False
# 358-1921       False       False        False         False      False
# 375-9999       False       False        False         False      False
# 330-6626       False       False        False         False      False
# 391-8027       False       False        False         False      False
# 355-9993       False       False        False         False      False
# 329-9001       False       False        False         False      False
# 335-4719       False       False        False         False      False
# 330-8173       False       False        False         False      False
# 329-6603       False       False        False         False      False
# 344-9403       False       False        False         False      False
# 363-1107       False       False        False         False      False
# 394-8006       False       False        False         False      False
# 366-9238       False       False        False         False      False
# 351-7269       False       False        False         False      False
# 350-8884       False       False        False         False      False
# 386-2923       False       False        False         False      False
# 356-2992       False       False        False         False      False
# 373-2782       False       False        False         False      False
# 396-5800       False       False        False         False      False
# 393-7984       False       False        False         False      False
# 358-1958       False       False        False         False      False
# 350-2565       False       False        False         False      False
# 343-4696       False       False        False         False      False
# 331-3698       False       False        False         False      False
# 357-3817       False       False        False         False      False
# 418-6412       False       False        False         False      False
# 353-2630       False       False        False         False      False
# 410-7789       False       False        False         False      False
# ...              ...         ...          ...           ...        ...
# 373-7308       False       False        False         False      False
# 330-7137       False       False        False         False      False
# 406-8445       False       False        False         False      False
# 404-5283       False       False        False         False      False
# 398-3632       False       False        False         False      False
# 399-5763       False       False        False         False      False
# 340-9449       False       False        False         False      False
# 363-1123       False       False        False         False      False
# 361-2170       False       False        False         False      False
# 406-6304       False       False        False         False      False
# 392-5090       False       False        False         False      False
# 373-7713       False       False        False         False      False
# 392-1376       False       False        False         False      False
# 390-6388       False       False        False         False      False
# 379-7290       False       False        False         False      False
# 397-9928       False       False        False         False      False
# 378-6924       False       False        False         False      False
# 411-5677       False       False        False         False      False
# 400-2738       False       False        False         False      False
# 409-1856       False       False        False         False      False
# 362-5899       False       False        False         False      False
# 377-1164       False       False        False         False      False
# 368-8555       False       False        False         False      False
# 347-6812       False       False        False         False      False
# 348-3830       False       False        False         False      False
# 414-4276       False       False        False         False      False
# 370-3271       False       False        False         False      False
# 328-8230       False       False        False         False      False
# 364-6381       False       False        False         False      False
# 400-4344       False       False        False         False      False
#
#           Intl Calls  Intl Charge  CustServ Calls  Churn?
# Phone
# 382-4657       False        False           False   False
# 371-7191       False        False           False   False
# 358-1921       False        False           False   False
# 375-9999       False        False           False   False
# 330-6626       False        False           False   False
# 391-8027       False        False           False   False
# 355-9993       False        False           False   False
# 329-9001       False        False           False   False
# 335-4719       False        False           False   False
# 330-8173       False        False           False   False
# 329-6603       False        False           False   False
# 344-9403       False        False           False   False
# 363-1107       False        False           False   False
# 394-8006       False        False           False   False
# 366-9238       False        False           False   False
# 351-7269       False        False           False   False
# 350-8884       False        False           False   False
# 386-2923       False        False           False   False
# 356-2992       False        False           False   False
# 373-2782       False        False           False   False
# 396-5800       False        False           False   False
# 393-7984       False        False           False   False
# 358-1958       False        False           False   False
# 350-2565       False        False           False   False
# 343-4696       False        False           False   False
# 331-3698       False        False           False   False
# 357-3817       False        False           False   False
# 418-6412       False        False           False   False
# 353-2630       False        False           False   False
# 410-7789       False        False           False   False
# ...              ...          ...             ...     ...
# 373-7308       False        False           False   False
# 330-7137       False        False           False   False
# 406-8445       False        False           False   False
# 404-5283       False        False           False   False
# 398-3632       False        False           False   False
# 399-5763       False        False           False   False
# 340-9449       False        False           False   False
# 363-1123       False        False           False   False
# 361-2170       False        False           False   False
# 406-6304       False        False           False   False
# 392-5090       False        False           False   False
# 373-7713       False        False           False   False
# 392-1376       False        False           False   False
# 390-6388       False        False           False   False
# 379-7290       False        False           False   False
# 397-9928       False        False           False   False
# 378-6924       False        False           False   False
# 411-5677       False        False           False   False
# 400-2738       False        False           False   False
# 409-1856       False        False           False   False
# 362-5899       False        False           False   False
# 377-1164       False        False           False   False
# 368-8555       False        False           False   False
# 347-6812       False        False           False   False
# 348-3830       False        False           False   False
# 414-4276       False        False           False   False
# 370-3271       False        False           False   False
# 328-8230       False        False           False   False
# 364-6381       False        False           False   False
# 400-4344       False        False           False   False
#
# [3333 rows x 21 columns]

# %% [markdown]
# This doesn't look so pretty and is hard to look at. We can do the following:

# %%
df.isna().sum() / df.shape[0]
# Out:
# State             0.0
# Account Length    0.0
# Area Code         0.0
# Phone             0.0
# Int'l Plan        0.0
# VMail Plan        0.0
# VMail Message     0.0
# Day Mins          0.0
# Day Calls         0.0
# Day Charge        0.0
# Eve Mins          0.0
# Eve Calls         0.0
# Eve Charge        0.0
# Night Mins        0.0
# Night Calls       0.0
# Night Charge      0.0
# Intl Mins         0.0
# Intl Calls        0.0
# Intl Charge       0.0
# CustServ Calls    0.0
# Churn?            0.0
# dtype: float64

# %% [markdown]
# Here we don't have any missing values, but if we did we could fill them using different approaches: fill with 0, with mean value, median values... Since we don't have any missing values the function won't do anything.

# %%
df.fillna(0)
# Out:
#          State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan  \
# Phone
# 382-4657    KS             128        415  382-4657           0           1
# 371-7191    OH             107        415  371-7191           0           1
# 358-1921    NJ             137        415  358-1921           0           0
# 375-9999    OH              84        408  375-9999           1           0
# 330-6626    OK              75        415  330-6626           1           0
# 391-8027    AL             118        510  391-8027           1           0
# 355-9993    MA             121        510  355-9993           0           1
# 329-9001    MO             147        415  329-9001           1           0
# 335-4719    LA             117        408  335-4719           0           0
# 330-8173    WV             141        415  330-8173           1           1
# 329-6603    IN              65        415  329-6603           0           0
# 344-9403    RI              74        415  344-9403           0           0
# 363-1107    IA             168        408  363-1107           0           0
# 394-8006    MT              95        510  394-8006           0           0
# 366-9238    IA              62        415  366-9238           0           0
# 351-7269    NY             161        415  351-7269           0           0
# 350-8884    ID              85        408  350-8884           0           1
# 386-2923    VT              93        510  386-2923           0           0
# 356-2992    VA              76        510  356-2992           0           1
# 373-2782    TX              73        415  373-2782           0           0
# 396-5800    FL             147        415  396-5800           0           0
# 393-7984    CO              77        408  393-7984           0           0
# 358-1958    AZ             130        415  358-1958           0           0
# 350-2565    SC             111        415  350-2565           0           0
# 343-4696    VA             132        510  343-4696           0           0
# 331-3698    NE             174        415  331-3698           0           0
# 357-3817    WY              57        408  357-3817           0           1
# 418-6412    MT              54        408  418-6412           0           0
# 353-2630    MO              20        415  353-2630           0           0
# 410-7789    HI              49        510  410-7789           0           0
# ...        ...             ...        ...       ...         ...         ...
# 373-7308    WI             114        415  373-7308           0           1
# 330-7137    IL              71        510  330-7137           1           0
# 406-8445    IN              58        415  406-8445           0           1
# 404-5283    AL             106        408  404-5283           0           1
# 398-3632    OK             172        408  398-3632           0           0
# 399-5763    IA              45        415  399-5763           0           0
# 340-9449    VT             100        408  340-9449           1           0
# 363-1123    NY              94        415  363-1123           0           0
# 361-2170    LA             128        415  361-2170           0           0
# 406-6304    SC             181        408  406-6304           0           0
# 392-5090    ID             127        408  392-5090           0           0
# 373-7713    MO              89        415  373-7713           0           0
# 392-1376    ME             149        415  392-1376           0           1
# 390-6388    MS             103        510  390-6388           0           1
# 379-7290    SD             163        415  379-7290           1           0
# 397-9928    OK              52        415  397-9928           0           0
# 378-6924    WY              89        415  378-6924           0           0
# 411-5677    GA             122        510  411-5677           1           0
# 400-2738    VT              60        415  400-2738           0           0
# 409-1856    MD              62        408  409-1856           0           0
# 362-5899    IN             117        415  362-5899           0           0
# 377-1164    WV             159        415  377-1164           0           0
# 368-8555    OH              78        408  368-8555           0           0
# 347-6812    OH              96        415  347-6812           0           0
# 348-3830    SC              79        415  348-3830           0           0
# 414-4276    AZ             192        415  414-4276           0           1
# 370-3271    WV              68        415  370-3271           0           0
# 328-8230    RI              28        510  328-8230           0           0
# 364-6381    CT             184        510  364-6381           1           0
# 400-4344    TN              74        415  400-4344           0           1
#
#           VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# Phone
# 382-4657             25     265.1        110       45.07     197.4         99
# 371-7191             26     161.6        123       27.47     195.5        103
# 358-1921              0     243.4        114       41.38     121.2        110
# 375-9999              0     299.4         71       50.90      61.9         88
# 330-6626              0     166.7        113       28.34     148.3        122
# 391-8027              0     223.4         98       37.98     220.6        101
# 355-9993             24     218.2         88       37.09     348.5        108
# 329-9001              0     157.0         79       26.69     103.1         94
# 335-4719              0     184.5         97       31.37     351.6         80
# 330-8173             37     258.6         84       43.96     222.0        111
# 329-6603              0     129.1        137       21.95     228.5         83
# 344-9403              0     187.7        127       31.91     163.4        148
# 363-1107              0     128.8         96       21.90     104.9         71
# 394-8006              0     156.6         88       26.62     247.6         75
# 366-9238              0     120.7         70       20.52     307.2         76
# 351-7269              0     332.9         67       56.59     317.8         97
# 350-8884             27     196.4        139       33.39     280.9         90
# 386-2923              0     190.7        114       32.42     218.2        111
# 356-2992             33     189.7         66       32.25     212.8         65
# 373-2782              0     224.4         90       38.15     159.5         88
# 396-5800              0     155.1        117       26.37     239.7         93
# 393-7984              0      62.4         89       10.61     169.9        121
# 358-1958              0     183.0        112       31.11      72.9         99
# 350-2565              0     110.4        103       18.77     137.3        102
# 343-4696              0      81.1         86       13.79     245.2         72
# 331-3698              0     124.3         76       21.13     277.1        112
# 357-3817             39     213.0        115       36.21     191.1        112
# 418-6412              0     134.3         73       22.83     155.5        100
# 353-2630              0     190.0        109       32.30     258.2         84
# 410-7789              0     119.3        117       20.28     215.1        109
# ...                 ...       ...        ...         ...       ...        ...
# 373-7308             26     137.1         88       23.31     155.7        125
# 330-7137              0     186.1        114       31.64     198.6        140
# 406-8445             22     224.1        127       38.10     238.8         85
# 404-5283             29      83.6        131       14.21     203.9        131
# 398-3632              0     203.9        109       34.66     234.0        123
# 399-5763              0     211.3         87       35.92     165.7         97
# 340-9449              0     219.4        112       37.30     225.7        102
# 363-1123              0     190.4         91       32.37      92.0        107
# 361-2170              0     147.7         94       25.11     283.3         83
# 406-6304              0     229.9        130       39.08     144.4         93
# 392-5090              0     102.8        128       17.48     143.7         95
# 373-7713              0     178.7         81       30.38     233.7         74
# 392-1376             18     148.5        106       25.25     114.5        106
# 390-6388             29     164.1        111       27.90     219.1         96
# 379-7290              0     197.2         90       33.52     188.5        113
# 397-9928              0     124.9        131       21.23     300.5        118
# 378-6924              0     115.4         99       19.62     209.9        115
# 411-5677              0     140.0        101       23.80     196.4         77
# 400-2738              0     193.9        118       32.96      85.0        110
# 409-1856              0     321.1        105       54.59     265.5        122
# 362-5899              0     118.4        126       20.13     249.3         97
# 377-1164              0     169.8        114       28.87     197.7        105
# 368-8555              0     193.4         99       32.88     116.9         88
# 347-6812              0     106.6        128       18.12     284.8         87
# 348-3830              0     134.7         98       22.90     189.7         68
# 414-4276             36     156.2         77       26.55     215.5        126
# 370-3271              0     231.1         57       39.29     153.4         55
# 328-8230              0     180.8        109       30.74     288.8         58
# 364-6381              0     213.8        105       36.35     159.6         84
# 400-4344             25     234.4        113       39.85     265.9         82
#
#           Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# Phone
# 382-4657       16.78       244.7           91         11.01       10.0
# 371-7191       16.62       254.4          103         11.45       13.7
# 358-1921       10.30       162.6          104          7.32       12.2
# 375-9999        5.26       196.9           89          8.86        6.6
# 330-6626       12.61       186.9          121          8.41       10.1
# 391-8027       18.75       203.9          118          9.18        6.3
# 355-9993       29.62       212.6          118          9.57        7.5
# 329-9001        8.76       211.8           96          9.53        7.1
# 335-4719       29.89       215.8           90          9.71        8.7
# 330-8173       18.87       326.4           97         14.69       11.2
# 329-6603       19.42       208.8          111          9.40       12.7
# 344-9403       13.89       196.0           94          8.82        9.1
# 363-1107        8.92       141.1          128          6.35       11.2
# 394-8006       21.05       192.3          115          8.65       12.3
# 366-9238       26.11       203.0           99          9.14       13.1
# 351-7269       27.01       160.6          128          7.23        5.4
# 350-8884       23.88        89.3           75          4.02       13.8
# 386-2923       18.55       129.6          121          5.83        8.1
# 356-2992       18.09       165.7          108          7.46       10.0
# 373-2782       13.56       192.8           74          8.68       13.0
# 396-5800       20.37       208.8          133          9.40       10.6
# 393-7984       14.44       209.6           64          9.43        5.7
# 358-1958        6.20       181.8           78          8.18        9.5
# 350-2565       11.67       189.6          105          8.53        7.7
# 343-4696       20.84       237.0          115         10.67       10.3
# 331-3698       23.55       250.7          115         11.28       15.5
# 357-3817       16.24       182.7          115          8.22        9.5
# 418-6412       13.22       102.1           68          4.59       14.7
# 353-2630       21.95       181.5          102          8.17        6.3
# 410-7789       18.28       178.7           90          8.04       11.1
# ...              ...         ...          ...           ...        ...
# 373-7308       13.23       247.6           94         11.14       11.5
# 330-7137       16.88       206.5           80          9.29       13.8
# 406-8445       20.30       174.2           86          7.84       11.5
# 404-5283       17.33       229.5           73         10.33        8.1
# 398-3632       19.89       160.7           65          7.23       17.8
# 399-5763       14.08       265.9           72         11.97       13.3
# 340-9449       19.18       255.3           95         11.49       12.0
# 363-1123        7.82       224.8          108         10.12       13.6
# 361-2170       24.08       188.3          124          8.47        6.9
# 406-6304       12.27       262.4          110         11.81       14.2
# 392-5090       12.21       191.4           97          8.61       10.0
# 373-7713       19.86       131.9          120          5.94        9.1
# 392-1376        9.73       178.3           98          8.02        6.5
# 390-6388       18.62       220.3          108          9.91       12.3
# 379-7290       16.02       211.1           94          9.50        7.8
# 397-9928       25.54       192.5          106          8.66       11.6
# 378-6924       17.84       280.9          112         12.64       15.9
# 411-5677       16.69       120.1          133          5.40        9.7
# 400-2738        7.23       210.1          134          9.45       13.2
# 409-1856       22.57       180.5           72          8.12       11.5
# 362-5899       21.19       227.0           56         10.22       13.6
# 377-1164       16.80       193.7           82          8.72       11.6
# 368-8555        9.94       243.3          109         10.95        9.3
# 347-6812       24.21       178.9           92          8.05       14.9
# 348-3830       16.12       221.4          128          9.96       11.8
# 414-4276       18.32       279.1           83         12.56        9.9
# 370-3271       13.04       191.3          123          8.61        9.6
# 328-8230       24.55       191.9           91          8.64       14.1
# 364-6381       13.57       139.2          137          6.26        5.0
# 400-4344       22.60       241.4           77         10.86       13.7
#
#           Intl Calls  Intl Charge  CustServ Calls  Churn?
# Phone
# 382-4657           3         2.70               1       0
# 371-7191           3         3.70               1       0
# 358-1921           5         3.29               0       0
# 375-9999           7         1.78               2       0
# 330-6626           3         2.73               3       0
# 391-8027           6         1.70               0       0
# 355-9993           7         2.03               3       0
# 329-9001           6         1.92               0       0
# 335-4719           4         2.35               1       0
# 330-8173           5         3.02               0       0
# 329-6603           6         3.43               4       1
# 344-9403           5         2.46               0       0
# 363-1107           2         3.02               1       0
# 394-8006           5         3.32               3       0
# 366-9238           6         3.54               4       0
# 351-7269           9         1.46               4       1
# 350-8884           4         3.73               1       0
# 386-2923           3         2.19               3       0
# 356-2992           5         2.70               1       0
# 373-2782           2         3.51               1       0
# 396-5800           4         2.86               0       0
# 393-7984           6         1.54               5       1
# 358-1958          19         2.57               0       0
# 350-2565           6         2.08               2       0
# 343-4696           2         2.78               0       0
# 331-3698           5         4.19               3       0
# 357-3817           3         2.57               0       0
# 418-6412           4         3.97               3       0
# 353-2630           6         1.70               0       0
# 410-7789           1         3.00               1       0
# ...              ...          ...             ...     ...
# 373-7308           7         3.11               2       0
# 330-7137           5         3.73               4       1
# 406-8445           7         3.11               2       0
# 404-5283           3         2.19               1       0
# 398-3632           4         4.81               4       0
# 399-5763           6         3.59               1       0
# 340-9449           4         3.24               4       0
# 363-1123          17         3.67               2       0
# 361-2170           5         1.86               2       0
# 406-6304           4         3.83               2       0
# 392-5090           5         2.70               1       0
# 373-7713           4         2.46               1       0
# 392-1376           4         1.76               0       0
# 390-6388           9         3.32               0       0
# 379-7290           8         2.11               1       0
# 397-9928           4         3.13               2       0
# 378-6924           6         4.29               3       0
# 411-5677           4         2.62               4       1
# 400-2738           8         3.56               3       0
# 409-1856           2         3.11               4       1
# 362-5899           3         3.67               5       1
# 377-1164           4         3.13               1       0
# 368-8555           4         2.51               2       0
# 347-6812           7         4.02               1       0
# 348-3830           5         3.19               2       0
# 414-4276           6         2.67               2       0
# 370-3271           4         2.59               3       0
# 328-8230           6         3.81               2       0
# 364-6381          10         1.35               2       0
# 400-4344           4         3.70               0       0
#
# [3333 rows x 21 columns]

# %% [markdown]
# ### Adding and deleting columns<br>
# It wouldn't be data manipulation if we can't add and delete features of our dataset. The functions used here are `insert()` and `drop()`.

# %%
df.insert(loc=len(df.columns), column='Total Calls', value= df['Day Calls'] + df['Eve Calls']+df['Night Calls'])
df.head()
# Out:
#          State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan  \
# Phone
# 382-4657    KS             128        415  382-4657           0           1
# 371-7191    OH             107        415  371-7191           0           1
# 358-1921    NJ             137        415  358-1921           0           0
# 375-9999    OH              84        408  375-9999           1           0
# 330-6626    OK              75        415  330-6626           1           0
#
#           VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# Phone
# 382-4657             25     265.1        110       45.07     197.4         99
# 371-7191             26     161.6        123       27.47     195.5        103
# 358-1921              0     243.4        114       41.38     121.2        110
# 375-9999              0     299.4         71       50.90      61.9         88
# 330-6626              0     166.7        113       28.34     148.3        122
#
#           Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# Phone
# 382-4657       16.78       244.7           91         11.01       10.0
# 371-7191       16.62       254.4          103         11.45       13.7
# 358-1921       10.30       162.6          104          7.32       12.2
# 375-9999        5.26       196.9           89          8.86        6.6
# 330-6626       12.61       186.9          121          8.41       10.1
#
#           Intl Calls  Intl Charge  CustServ Calls  Churn?  Total Calls
# Phone
# 382-4657           3         2.70               1       0          300
# 371-7191           3         3.70               1       0          329
# 358-1921           5         3.29               0       0          328
# 375-9999           7         1.78               2       0          248
# 330-6626           3         2.73               3       0          356

# %% [markdown]
# The column was added at the index location of `len(df.columns)` which means it was added at the end as we can see. This approach is useful when we need to add the column at the exact location, but there's a more intuitive approach. Before we can show it, let's delete the new column.

# %%
df.drop(['Total Calls'], axis = 1, inplace=True)

# %%
df['Total Calls'] = df['Day Calls'] + df['Eve Calls']+df['Night Calls']
df.head()
# Out:
#          State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan  \
# Phone
# 382-4657    KS             128        415  382-4657           0           1
# 371-7191    OH             107        415  371-7191           0           1
# 358-1921    NJ             137        415  358-1921           0           0
# 375-9999    OH              84        408  375-9999           1           0
# 330-6626    OK              75        415  330-6626           1           0
#
#           VMail Message  Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# Phone
# 382-4657             25     265.1        110       45.07     197.4         99
# 371-7191             26     161.6        123       27.47     195.5        103
# 358-1921              0     243.4        114       41.38     121.2        110
# 375-9999              0     299.4         71       50.90      61.9         88
# 330-6626              0     166.7        113       28.34     148.3        122
#
#           Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# Phone
# 382-4657       16.78       244.7           91         11.01       10.0
# 371-7191       16.62       254.4          103         11.45       13.7
# 358-1921       10.30       162.6          104          7.32       12.2
# 375-9999        5.26       196.9           89          8.86        6.6
# 330-6626       12.61       186.9          121          8.41       10.1
#
#           Intl Calls  Intl Charge  CustServ Calls  Churn?  Total Calls
# Phone
# 382-4657           3         2.70               1       0          300
# 371-7191           3         3.70               1       0          329
# 358-1921           5         3.29               0       0          328
# 375-9999           7         1.78               2       0          248
# 330-6626           3         2.73               3       0          356

# %% [markdown]
# This approach adds the new column automatically at the end of the dataset.

# %% [markdown]
# ## Statistics<br>
# In order to find out the information we need, we can use different statistical measures and approaches. Using the `mean()` function, we can have a look at the average churner.

# %%
df[df['Churn?'] == 1].mean()
# Out:
# Account Length    102.66
# Area Code         437.82
# Int'l Plan          0.28
# VMail Plan          0.17
# VMail Message       5.12
# Day Mins          206.91
# Day Calls         101.34
# Day Charge         35.18
# Eve Mins          212.41
# Eve Calls         100.56
# Eve Charge         18.05
# Night Mins        205.23
# Night Calls       100.40
# Night Charge        9.24
# Intl Mins          10.70
# Intl Calls          4.16
# Intl Charge         2.89
# CustServ Calls      2.23
# Churn?              1.00
# Total Calls       302.30
# dtype: float64

# %% [markdown]
# We can also use multiple statistical measures to apply to the data. We can do that with the `agg()` function whose parameter is a list of statistical measures to apply in string format.

# %%
df[df['Churn?'] == 1].agg(['mean', 'median'])
# Out:
#         Account Length  Area Code  Int'l Plan  VMail Plan  VMail Message  \
# mean            102.66     437.82        0.28        0.17           5.12
# median          103.00     415.00        0.00        0.00           0.00
#
#         Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  Eve Charge  \
# mean      206.91     101.34       35.18    212.41     100.56       18.05
# median    217.60     103.00       36.99    211.30     101.00       17.96
#
#         Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# mean        205.23        100.4          9.24       10.7        4.16
# median      204.80        100.0          9.22       10.6        4.00
#
#         Intl Charge  CustServ Calls  Churn?  Total Calls
# mean           2.89            2.23     1.0        302.3
# median         2.86            2.00     1.0        302.0

# %% [markdown]
# Even though this is useful, we are more likely to need information about the relationship between two or more features grouped by some values. In this case, we group by `Churn?` feature and show standard deviation and mean values for the day, eve and night calls.

# %%
columns_to_show = ['Day Calls', 'Eve Calls', 'Night Calls']
df.groupby(['Churn?'])[columns_to_show].agg(['mean', 'std'])
# Out:
#        Day Calls        Eve Calls        Night Calls
#             mean    std      mean    std        mean    std
# Churn?
# 0         100.28  19.80    100.04  19.96      100.06  19.51
# 1         101.34  21.58    100.56  19.72      100.40  19.95

# %% [markdown]
# `groupby()` function works in the following manner:<br>
# <center>df.groupby( [columns_to_group_by] )[columns_to_show].agg( [functions_to_apply] )</center>

# %% [markdown]
# In other cases, we are interested in the relationship between two categorical features. The statistical term for this type of table is <b>contingency table</b>. As before, we use normalize parameter to show percentages instead of raw numbers.

# %%
pd.crosstab(df['Churn?'], df['VMail Plan'], normalize=True)
# Out:
# VMail Plan     0     1
# Churn?
# 0           0.60  0.25
# 1           0.12  0.02

# %% [markdown]
# As can be seen from the table above, most clients who are loyal, don't use voice mail plan.<br>
# Lastly, we'll have a look at the pivot tables. `pivot_table()` function works like this:<br>
# <center>df.pivot_table( values= [features_to_calc_stats_for], index= [features_to_group_by], aggfunc= [ stat_funcs_to_apply] )</center>

# %%
df.pivot_table(values=columns_to_show, index=['Churn?'], aggfunc=['mean', 'std'])
# Out:
#             mean                             std
#        Day Calls Eve Calls Night Calls Day Calls Eve Calls Night Calls
# Churn?
# 0         100.28    100.04      100.06     19.80     19.96       19.51
# 1         101.34    100.56      100.40     21.58     19.72       19.95

# %% [markdown]
# We got the similar result to the `groupby()` function result!

# %% [markdown]
# ## Additional resources:
# <ul><li>Official Pandas <a href='https://pandas.pydata.org/pandas-docs/stable/index.html'>documentation</a></li>
#     <li>Pandas <a href='https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf'>cheatsheet</a></li>
#     <li>Pandas <a href='https://github.com/guipsamora/pandas_exercises/'>exercises</a></li></ul>
